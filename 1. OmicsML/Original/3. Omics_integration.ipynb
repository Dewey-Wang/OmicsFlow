# %%
import pandas as pd

proteome = pd.read_csv("/Users/deweywang/Desktop/GitHub/OmicsFlow/1. OmicsML/dataset/processed/2. Data_cleaning/Proteome/Proteome.csv")
rna_seq = pd.read_csv("/Users/deweywang/Desktop/GitHub/OmicsFlow/1. OmicsML/dataset/processed/2. Data_cleaning/RNA-seq/prot+lncRNA.csv")

# %%
import pandas as pd
clinical_data = pd.read_csv("/Users/deweywang/Desktop/GitHub/OmicsFlow/1. OmicsML/dataset/raw_dataset/Proteomics/Primary_tumor/PDC_clinical_data_manifests_02152025_021621/PDC_clinical_manifest_02152025_021621.tsv", sep='\t')

# %% [markdown]
# ## Tumor information:

# %%
clinical_data["Primary Diagnosis"].unique()
# Out:
# array(['Infiltrating duct carcinoma, NOS', 'Not Reported',
#        'Infiltrating duct and lobular carcinoma',
#        'Infiltrating duct and mucinous carcinoma',
#        'Infiltrating lobular carcinoma, NOS',
#        'Intraductal papillary carcinoma', 'Adenocarcinoma, NOS',
#        'Invasive lobular carcinoma', 'Squamous cell carcinoma, NOS',
#        'Mucinous carcinoma'], dtype=object)

# %%
clinical_data["Tumor Stage"].unique()
# Out:
# array(['Stage IIA', 'Not Reported', 'Stage IIB', 'Stage IIIC',
#        'Stage IIIA', 'Stage IIIB', 'Stage III', 'Stage II', 'Stage IA',
#        'Not Performed'], dtype=object)

# %%
clinical_data["Morphology"].unique()
# Out:
# array([' '], dtype=object)

# %% [markdown]
# ##
